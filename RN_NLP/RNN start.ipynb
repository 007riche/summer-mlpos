# %%
import numpy as np

# %%
#Generate random data
time =np.arange(0, 1500)

# %%
time
# Out:
# array([   0,    1,    2, ..., 1497, 1498, 1499])

# %%
y=np.sin(t)
#get lesser frequency
profit=np.sin(0.02*time)

# %%
profit
# Out:
# array([ 0.        ,  0.01999867,  0.03998933, ..., -0.99550324,
#        -0.99340972, -0.99091885])

# %%
profit.shape
# Out:
# (1500,)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(profit)

# %%
np.linspace(0, 10, #RAnge
            20 #number of values generated 
            )
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
np.pi # Pi value 3.14
# Out:
# 3.141592653589793

# %%
inp=np.linspace(-np.pi, np.pi,
            20 
            )

# %%
opt = np.sin(inp)

# %%
plt.plot(inp, opt, marker='o')

# %%
rProfit_withnoise= np.sin(0.02*time) + np.random.uniform(low=-1, high=1, size=(1500,)) #random Value

# %%
plt.plot(rProfit)
